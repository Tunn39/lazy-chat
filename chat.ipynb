# %%
pip install streamlit openai
# Out:
# Collecting streamlit
#   Downloading streamlit-1.48.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: openai in d:\data learning\anacolda\envs\datascience\lib\site-packages (1.100.2)
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Downloading cachetools-6.1.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<26,>=20 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (10.4.0)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-21.0.0-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (2.32.3)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in d:\data learning\anacolda\envs\datascience\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from openai) (4.66.6)
# Requirement already satisfied: jinja2 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit)
#   Downloading narwhals-2.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: idna>=2.8 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: colorama in d:\data learning\anacolda\envs\datascience\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: certifi in d:\data learning\anacolda\envs\datascience\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\data learning\anacolda\envs\datascience\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: six>=1.5 in d:\data learning\anacolda\envs\datascience\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.48.1-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----------------- ---------------------- 4.5/9.9 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 33.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 23.8 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 7.4 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.1.0-py3-none-any.whl (11 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading protobuf-6.32.0-cp310-abi3-win_amd64.whl (435 kB)
# Downloading pyarrow-21.0.0-cp310-cp310-win_amd64.whl (26.2 MB)
#    ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#    -------------- ------------------------- 9.4/26.2 MB 48.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.9/26.2 MB 45.8 MB/s eta 0:00:01
#    ---------------------------------------  26.2/26.2 MB 46.1 MB/s eta 0:00:01
#    ---------------------------------------  26.2/26.2 MB 46.1 MB/s eta 0:00:01
#    ---------------------------------------- 26.2/26.2 MB 30.8 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------------------------------------ --- 6.3/6.9 MB 35.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 20.2 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-2.1.2-py3-none-any.whl (392 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, protobuf, narwhals, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-6.1.0 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.1.2 protobuf-6.32.0 pyarrow-21.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.48.1 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from openai import OpenAI
import os

# Make sure your API key is set in your environment
# Example (Linux/Mac): export OPENAI_API_KEY="sk-proj-xxxx..."
# Example (Windows PowerShell): setx OPENAI_API_KEY "sk-proj-xxxx..."

client = OpenAI()

def rewrite_professional(message: str) -> str:
    """
    Rewrite message with a firm, professional tone and clear boundaries.
    """
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4o", "gpt-5" if available
        messages=[
            {"role": "system", "content": "Rewrite text in a firm, professional tone with clear boundaries."},
            {"role": "user", "content": message}
        ],
        temperature=0.3
    )
    return response.choices[0].message.content.strip()


# --- Streamlit App UI ---
st.set_page_config(page_title="Professional Rewriter", page_icon="💼")

st.title("💼 Professional Message Rewriter")
st.write("Type your message below and get a firm, professional rewrite with clear boundaries.")

user_input = st.text_area("✍️ Your message:", height=150)

if st.button("Rephrase"):
    if user_input.strip():
        rewritten = rewrite_professional(user_input)
        st.subheader("✅ Professional Rewrite")
        st.success(rewritten)
    else:
        st.warning("Please enter a message first.")
# Out:
# 2025-08-20 11:51:34.179 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:34.193 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.101
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run D:\DATA Learning\Anacolda\envs\datascience\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-08-20 11:51:35.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.110 Session state does not function when running a script without `streamlit run`
# 2025-08-20 11:51:35.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 11:51:35.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
